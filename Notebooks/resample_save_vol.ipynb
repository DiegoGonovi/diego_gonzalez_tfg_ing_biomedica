# %%
import ipynb
import glob
import nibabel as nib
from PIL import Image
import numpy as np
from scipy.ndimage import zoom
import cv2      
import os

# %%
# Importar funciones
# %run Funciones.ipynb

# %%
path = 'C:/Users/DiegoGO/Desktop/Diego/ING. BIOMÉDICA/5º Carrera/TFG/ProyectoTFG/Pacientes_Yolo/*' 
# Path de los pacientes
pat_list = glob.glob(path)

for pat in pat_list:
    print('nódulo')        
    node_img = glob.glob(pat + '/node_segmentation.nii.gz') # Selección de la img del nodo segmentada
    resample_nifti_to_1mm(node_img[0], pat + '/node_segmentation_resampled.nii.gz', binary=True)
    print('imagen')
    full_img = glob.glob(pat + '/image.nii.gz') # Selección de la full img
    resample_nifti_to_1mm(full_img[0], pat + '/image_resampled.nii.gz')
    
    print(pat)
# Out:
# nódulo
# Original data shape: (512, 512, 366)
# Resampled data shape: (512, 512, 549)
# imagen
# Original data shape: (512, 512, 366)
# Resampled data shape: (512, 512, 549)
# C:/Users/DiegoGO/Desktop/Diego/ING. BIOMÉDICA/5º Carrera/TFG/ProyectoTFG/Pacientes_Yolo\001
# nódulo
# Original data shape: (512, 512, 367)
# Resampled data shape: (512, 512, 550)
# imagen
# Original data shape: (512, 512, 367)
# Resampled data shape: (512, 512, 550)
# C:/Users/DiegoGO/Desktop/Diego/ING. BIOMÉDICA/5º Carrera/TFG/ProyectoTFG/Pacientes_Yolo\002
# nódulo
# Original data shape: (512, 512, 440)
# Resampled data shape: (512, 512, 660)
# imagen
# Original data shape: (512, 512, 440)
# Resampled data shape: (512, 512, 660)
# C:/Users/DiegoGO/Desktop/Diego/ING. BIOMÉDICA/5º Carrera/TFG/ProyectoTFG/Pacientes_Yolo\004
# nódulo
# Original data shape: (512, 512, 445)
# Resampled data shape: (512, 512, 668)
# imagen
# Original data shape: (512, 512, 445)
# Resampled data shape: (512, 512, 668)
# ...
